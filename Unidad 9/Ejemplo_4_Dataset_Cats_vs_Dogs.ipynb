# %%
import kagglehub

# Alternativa más pequeña -> https://www.kaggle.com/datasets/chetankv/dogs-cats-images?select=dataset
# Download latest version
path = kagglehub.dataset_download("shaunthesheep/microsoft-catsvsdogs-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'microsoft-catsvsdogs-dataset' dataset.
# Path to dataset files: /kaggle/input/microsoft-catsvsdogs-dataset

# %%
import tensorflow as tf
print(tf.version.VERSION)
print("Dispositivos disponibles:", tf.config.list_physical_devices('GPU'))
# Out:
# 2.19.0
# Dispositivos disponibles: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import os
os.listdir(path)
# Out:
# ['PetImages', 'readme[1].txt', 'MSR-LA - 3467.docx']

# %%
path = '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages'
os.listdir(path)
# Out:
# ['Dog', 'Cat']

# %% [markdown]
# Crear directorios y separar imágenes de entrenamiento, validación y test

# %%
# !pip install split-folders
# Out:
# Requirement already satisfied: split-folders in /usr/local/lib/python3.12/dist-packages (0.5.1)

# %%
import splitfolders

output_folder = '/tmp/PetImages'
# 80% entrenamiento, 10% validación y 10% test
splitfolders.ratio(path, output=output_folder,
                   seed=42, ratio=(.8, .1, .1), group_prefix=None)
# Out:
# Copying files: 25002 files [02:20, 177.75 files/s]

# %%
train_dir = os.path.join(output_folder, 'train')
val_dir = os.path.join(output_folder, 'val')
test_dir = os.path.join(output_folder, 'test')

train_cats_dir = os.path.join(train_dir, 'Cat')
train_dogs_dir = os.path.join(train_dir, 'Dog')

val_cats_dir = os.path.join(test_dir, 'Cat')
val_dogs_dir = os.path.join(test_dir, 'Dog')

test_cats_dir = os.path.join(test_dir, 'Cat')
test_dogs_dir = os.path.join(test_dir, 'Dog')

print('Imágenes de entrenamiento de gatos :', len(os.listdir(train_cats_dir)))
print('Imágenes de entrenamiento de perros :', len(os.listdir(train_dogs_dir)))

print('Imágenes de Validación de gatos :', len(os.listdir(val_cats_dir)))
print('Imágenes de Validación de perros :', len(os.listdir(val_dogs_dir)))

print('Imágenes de prueba de gatos :', len(os.listdir(test_cats_dir)))
print('Imágenes de prueba de perros :', len(os.listdir(test_dogs_dir)))
# Out:
# Imágenes de entrenamiento de gatos : 10000
# Imágenes de entrenamiento de perros : 10000
# Imágenes de Validación de gatos : 1251
# Imágenes de Validación de perros : 1251
# Imágenes de prueba de gatos : 1251
# Imágenes de prueba de perros : 1251

# %% [markdown]
# ### Crear los 3 datasets

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 150

# Dividiremos el dataset de entrenamiento y asignamos un 80% a validación
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  seed=1234,
  batch_size=BATCH_SIZE)

validation_ds = tf.keras.utils.image_dataset_from_directory(
  val_dir,
  seed=1234,
  shuffle=False,
  batch_size=BATCH_SIZE)

# test dataset
test_ds = tf.keras.utils.image_dataset_from_directory(
  test_dir,
  seed=1234,
  shuffle=False,
  batch_size=BATCH_SIZE)
# Out:
# Found 19998 files belonging to 2 classes.
# Found 2500 files belonging to 2 classes.
# Found 2502 files belonging to 2 classes.

# %%
class_names = train_ds.class_names
class_names # Imprimimos clases (labels) de imágenes encontradas
# Out:
# ['Cat', 'Dog']

# %%
image_batch, label_batch = next(iter(train_ds)) # Obtenemos el primer lote de imágenes (32)

from matplotlib import pyplot as plt
plt.figure(figsize=(12, 6))
for i in range(8):  # Mostramos las 8 primeras imágenes del lote
  ax = plt.subplot(2, 4, i + 1)
  plt.imshow(image_batch[i].numpy().astype("uint8"))
  label = label_batch[i]
  plt.title(class_names[label])
  plt.axis("off")

# %% [markdown]
# ## Construyendo el modelo

# %%
# Cada vez que hagamos cambios en el modelo, debemos ejecutar esto primero
tf.keras.backend.clear_session()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Resizing, Rescaling, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, RandomRotation, RandomTranslation, RandomZoom, RandomFlip, BatchNormalization

# define model
model = Sequential([
    Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3)), # Define los datos de entrada
    Resizing(IMAGE_SIZE, IMAGE_SIZE), # Integramos el escalado de las imágenes en el modelo
    Rescaling(1./255), # Normalizamos en el modelo
    Conv2D(filters=64, kernel_size=(3,3), activation='relu'), # 148x148
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2),strides=(2,2)), # 74x74

    Conv2D(filters=64, kernel_size=(3,3), activation='relu'), # 72x72
    BatchNormalization(),
    MaxPooling2D(pool_size=(2,2),strides=(2,2)), # 36x36

    Conv2D(filters=32, kernel_size=(3,3), activation='relu'), # 34x34
    MaxPooling2D(pool_size=(2,2),strides=(2,2)), # 17x17
    BatchNormalization(),
    Dropout(0.3),

    Flatten(),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.4),
    Dense(1, activation='sigmoid') # La clasificación es binaria
])

# %%
# compile model
model.compile(optimizer = tf.optimizers.Adam(),
    loss = 'binary_crossentropy', # Función de pérdida en clasificación binaria
    metrics=['accuracy']
)

# Cuando no está predefinido el tamaño en el dataset (capa de entrada), hay que llamar a build y definirlo
# model.build(input_shape=(None,IMAGE_SIZE, IMAGE_SIZE, 3))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resizing (Resizing)             │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 148, 148, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 148, 148, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 72, 72, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 72, 72, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 34, 34, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 17, 17, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 17, 17, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 17, 17, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 9248)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     2,367,744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,426,849 (9.26 MB)
#  Trainable params: 2,426,017 (9.25 MB)
#  Non-trainable params: 832 (3.25 KB)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import tensorflow as tf

# Monitoreamos la pérdida en la validación. Detenemos después de 6 iteraciones sin mejorar. Restauramos mejores pesos
early_stop = EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',   # Monitorea la pérdida en validación
    factor=0.5,           # Reduce la tasa de aprendizaje a la mitad
    patience=3,           # Espera 3 iteraciones sin mejora antes de reducir
    min_lr=1e-6           # No permite que la tasa de aprendizaje baje de 1e-6
)

# Pipeline optimizado y sin Warnings
AUTOTUNE = tf.data.AUTOTUNE

train_ds = (
    train_ds
    .ignore_errors() # Nueva versión
    .prefetch(buffer_size=AUTOTUNE)
)

validation_ds = (
    validation_ds
    .ignore_errors() # Nueva versión
    .prefetch(buffer_size=AUTOTUNE)
)

history = model.fit(train_ds,
        epochs = 30,
        validation_data=(validation_ds),
        callbacks=[early_stop, reduce_lr]  # Agregar ambas estrategias
)
# Out:
# Epoch 1/30
#     618/Unknown 145s 218ms/step - accuracy: 0.6496 - loss: 0.7544
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 211s 324ms/step - accuracy: 0.6497 - loss: 0.7542 - val_accuracy: 0.6340 - val_loss: 0.6414 - learning_rate: 0.0010
# Epoch 2/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 121s 196ms/step - accuracy: 0.7797 - loss: 0.4567 - val_accuracy: 0.7977 - val_loss: 0.4379 - learning_rate: 0.0010
# Epoch 3/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 122s 198ms/step - accuracy: 0.8296 - loss: 0.3815 - val_accuracy: 0.7778 - val_loss: 0.4559 - learning_rate: 0.0010
# Epoch 4/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 122s 198ms/step - accuracy: 0.8604 - loss: 0.3189 - val_accuracy: 0.8279 - val_loss: 0.3717 - learning_rate: 0.0010
# Epoch 5/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 122s 197ms/step - accuracy: 0.8877 - loss: 0.2646 - val_accuracy: 0.8697 - val_loss: 0.2982 - learning_rate: 0.0010
# Epoch 6/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 123s 199ms/step - accuracy: 0.9122 - loss: 0.2122 - val_accuracy: 0.9221 - val_loss: 0.1956 - learning_rate: 0.0010
# Epoch 7/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 140s 227ms/step - accuracy: 0.9267 - loss: 0.1797 - val_accuracy: 0.9309 - val_loss: 0.1891 - learning_rate: 0.0010
# Epoch 8/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 145s 235ms/step - accuracy: 0.9407 - loss: 0.1522 - val_accuracy: 0.9499 - val_loss: 0.1355 - learning_rate: 0.0010
# Epoch 9/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 150s 243ms/step - accuracy: 0.9575 - loss: 0.1159 - val_accuracy: 0.9702 - val_loss: 0.0890 - learning_rate: 0.0010
# Epoch 10/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 151s 244ms/step - accuracy: 0.9642 - loss: 0.0963 - val_accuracy: 0.9297 - val_loss: 0.1989 - learning_rate: 0.0010
# Epoch 11/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 153s 247ms/step - accuracy: 0.9608 - loss: 0.1023 - val_accuracy: 0.9625 - val_loss: 0.0984 - learning_rate: 0.0010
# Epoch 12/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 152s 247ms/step - accuracy: 0.9734 - loss: 0.0742 - val_accuracy: 0.9887 - val_loss: 0.0441 - learning_rate: 0.0010
# Epoch 13/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 152s 246ms/step - accuracy: 0.9717 - loss: 0.0763 - val_accuracy: 0.9829 - val_loss: 0.0497 - learning_rate: 0.0010
# Epoch 14/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 152s 246ms/step - accuracy: 0.9736 - loss: 0.0663 - val_accuracy: 0.9866 - val_loss: 0.0407 - learning_rate: 0.0010
# Epoch 15/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 155s 250ms/step - accuracy: 0.9763 - loss: 0.0645 - val_accuracy: 0.9924 - val_loss: 0.0306 - learning_rate: 0.0010
# Epoch 16/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 159s 258ms/step - accuracy: 0.9812 - loss: 0.0501 - val_accuracy: 0.9402 - val_loss: 0.1530 - learning_rate: 0.0010
# Epoch 17/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 159s 257ms/step - accuracy: 0.9800 - loss: 0.0550 - val_accuracy: 0.9696 - val_loss: 0.0803 - learning_rate: 0.0010
# Epoch 18/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 155s 251ms/step - accuracy: 0.9752 - loss: 0.0659 - val_accuracy: 0.9845 - val_loss: 0.0506 - learning_rate: 0.0010
# Epoch 19/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 154s 249ms/step - accuracy: 0.9839 - loss: 0.0436 - val_accuracy: 0.9956 - val_loss: 0.0169 - learning_rate: 5.0000e-04
# Epoch 20/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 151s 245ms/step - accuracy: 0.9904 - loss: 0.0285 - val_accuracy: 0.9984 - val_loss: 0.0087 - learning_rate: 5.0000e-04
# Epoch 21/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 149s 242ms/step - accuracy: 0.9920 - loss: 0.0243 - val_accuracy: 0.9985 - val_loss: 0.0085 - learning_rate: 5.0000e-04
# Epoch 22/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 149s 242ms/step - accuracy: 0.9917 - loss: 0.0222 - val_accuracy: 0.9993 - val_loss: 0.0049 - learning_rate: 5.0000e-04
# Epoch 23/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 151s 244ms/step - accuracy: 0.9940 - loss: 0.0176 - val_accuracy: 0.9991 - val_loss: 0.0048 - learning_rate: 5.0000e-04
# Epoch 24/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 149s 241ms/step - accuracy: 0.9948 - loss: 0.0168 - val_accuracy: 0.9988 - val_loss: 0.0064 - learning_rate: 5.0000e-04
# Epoch 25/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 149s 240ms/step - accuracy: 0.9945 - loss: 0.0175 - val_accuracy: 0.9940 - val_loss: 0.0199 - learning_rate: 5.0000e-04
# Epoch 26/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 150s 243ms/step - accuracy: 0.9957 - loss: 0.0141 - val_accuracy: 0.9989 - val_loss: 0.0053 - learning_rate: 2.5000e-04
# Epoch 27/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 149s 241ms/step - accuracy: 0.9969 - loss: 0.0111 - val_accuracy: 0.9980 - val_loss: 0.0096 - learning_rate: 2.5000e-04
# Epoch 28/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 150s 242ms/step - accuracy: 0.9960 - loss: 0.0110 - val_accuracy: 0.9993 - val_loss: 0.0044 - learning_rate: 2.5000e-04
# Epoch 29/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 153s 247ms/step - accuracy: 0.9964 - loss: 0.0108 - val_accuracy: 0.9995 - val_loss: 0.0026 - learning_rate: 2.5000e-04
# Epoch 30/30
# 618/618 ━━━━━━━━━━━━━━━━━━━━ 153s 247ms/step - accuracy: 0.9975 - loss: 0.0079 - val_accuracy: 0.9995 - val_loss: 0.0028 - learning_rate: 2.5000e-04

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy curve')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss curve')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# Aplicamos la misma lógica para que no se detenga el proceso
test_ds_limpio = test_ds.ignore_errors().prefetch(buffer_size=tf.data.AUTOTUNE)

# Ahora evaluamos
results = model.evaluate(test_ds_limpio)
print(f"Loss: {results[0]}, Accuracy: {results[1]}")
# Out:
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.8791 - loss: 0.4936
# Loss: 0.4964432120323181, Accuracy: 0.8785424828529358

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Recuperar los nombres de las clases del dataset ORIGINAL
# (Suponiendo que test_ds fue creado con image_dataset_from_directory)
labels_names = test_ds.class_names

# 2. Obtener las predicciones y las etiquetas reales de forma sincronizada
y_true = []
y_pred_probs = []

# Iteramos sobre el dataset limpio para asegurar que solo procesamos lo que NO está corrupto
for images, labels in test_ds_limpio:
    preds = model.predict(images, verbose=0)
    y_true.extend(labels.numpy())
    y_pred_probs.extend(preds.ravel())

y_true = np.array(y_true)
y_pred = (np.array(y_pred_probs) > 0.5).astype(int)

# 3. Matriz de Confusión
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=labels_names,
            yticklabels=labels_names)
plt.title("Matriz de Confusión")
plt.ylabel("Realidad (True)")
plt.xlabel("Predicción (Predicted)")
plt.show()

# 4. Reporte de Clasificación (Precisión, Recall, F1)
print(classification_report(y_true, y_pred, target_names=labels_names))
# Out:
#               precision    recall  f1-score   support
#
#          Cat       0.88      0.88      0.88      1219
#          Dog       0.88      0.88      0.88      1251
#
#     accuracy                           0.88      2470
#    macro avg       0.88      0.88      0.88      2470
# weighted avg       0.88      0.88      0.88      2470

# %%
# Identificar los índices de las imágenes que se han clasificado incorrectamente
incorrect_indices = np.where(y_pred != y_true)[0]

print("Número total de imágenes mal clasificadas:", len(incorrect_indices))
num_show=10
index_show=incorrect_indices[:num_show]
single_element_ds = test_ds.unbatch()

# # Obtener la imagen en la posición 36 (indexada desde 0)

plt.figure(figsize=(12, 6))
for i in range(len(index_show)):
    index = index_show[i];
    imagen, etiqueta = list(single_element_ds.skip(index).take(1))[0]
    plt.subplot(2, (num_show + 1) // 2, i + 1)
    plt.imshow(imagen.numpy().astype("uint8"))
    plt.title(f"Real: {class_names[etiqueta]} | Predicho: {class_names[y_pred[index]]}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Número total de imágenes mal clasificadas: 300

# %%
import numpy as np
def classify(image_path):
  image = tf.keras.utils.load_img(image_path, color_mode='rgb')
  display(image)
  input_arr = tf.keras.utils.img_to_array(image)
  input_arr = np.array([input_arr])
  print(f'Tamaño de entrada: {input_arr.shape}')
  y_pred = model.predict(input_arr)
  print(f'Valores de salida: {y_pred[0][0]}')
  predicted_category_classname = class_names[round(y_pred[0][0])]
  print(f'Clasificación: {predicted_category_classname}')

# %%
classify('cat4.webp')
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1200x1200>
# Tamaño de entrada: (1, 1200, 1200, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Valores de salida: 0.0370723195374012
# Clasificación: Cat
